# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Although pandas is imported, it's not used in this version. Kept for potential future use.
import os

# --- Plotting Style Configuration ---
font_size_base = 14 
plt.rcParams.update({
    'font.size': font_size_base,
    'axes.titlesize': font_size_base + 2,
    'axes.labelsize': font_size_base,
    'xtick.labelsize': font_size_base - 2,
    'ytick.labelsize': font_size_base - 2,
    'legend.fontsize': font_size_base - 4, # Base legend size, adjusted dynamically later
    'figure.titlesize': font_size_base + 4 
})
output_dir = "./roofline_plots"

# --- System Parameters (Global for this hardware configuration) ---
MEM_BANDWIDTH_GB_s = 400  # GB/s
CLOCK_FREQ_MHZ = 940  # MHz
FLOPS_PER_PE_PER_CYCLE = 2
SRAM_CAPACITY_BYTES = 4 * 1024 * 1024 # 4MB Shared Global Buffer from arch-2d.yaml

# 2D PE Array
PE_ROWS_2D = 256
PE_COLS_2D = 256
NUM_PES_2D = PE_ROWS_2D * PE_COLS_2D

# 1D PE Array
NUM_PES_1D = 256 # 1x256

# --- Calculate Peak Performance (GFLOPs/s) ---
PEAK_PERF_2D_GFLOPS = (NUM_PES_2D * FLOPS_PER_PE_PER_CYCLE * CLOCK_FREQ_MHZ) / 1000
PEAK_PERF_1D_GFLOPS = (NUM_PES_1D * FLOPS_PER_PE_PER_CYCLE * CLOCK_FREQ_MHZ) / 1000

# --- Calculate Roofline Ridge Points (FLOPs/Byte) ---
RIDGE_POINT_2D = PEAK_PERF_2D_GFLOPS / MEM_BANDWIDTH_GB_s
RIDGE_POINT_1D = PEAK_PERF_1D_GFLOPS / MEM_BANDWIDTH_GB_s

# --- Workload Model Parameters ---
# BERT-Large like (Plot 1 & 2)
N_SEQ_REF_BERT = 1024
D_MODEL_BERT = 1024
N_HEADS_BERT = 16
D_HEAD_BERT = D_MODEL_BERT // N_HEADS_BERT
D_FF_BERT = D_MODEL_BERT * 4

# Pythia-14M (Plot 3 & 4)
N_SEQ_REF_PYTHIA = 2048 # Default seq len for component view
D_MODEL_PYTHIA = 128
N_HEADS_PYTHIA = 4
D_HEAD_PYTHIA = D_MODEL_PYTHIA // N_HEADS_PYTHIA
D_FF_PYTHIA = D_MODEL_PYTHIA * 4

# OPT-66B (Plot 3 & 4)
N_SEQ_REF_OPT = 2048 # Default seq len for component view
D_MODEL_OPT = 9216
N_HEADS_OPT = 72
D_HEAD_OPT = D_MODEL_OPT // N_HEADS_OPT
D_FF_OPT = 36864

BYTES_PER_ELEMENT_BF16 = 2
GELU_FLOPS_PER_ELEMENT = 10 
LAYERNORM_FLOPS_PER_ELEMENT = 5

# --- Helper function to calculate achieved performance ---
def get_achieved_perf(oi, peak_perf_for_type, bandwidth, ridge_point_for_type):
    """Calculates achieved performance based on OI for a specific roofline."""
    if oi <= 0: 
        return 0
    if oi < ridge_point_for_type:
        return oi * bandwidth
    else:
        return peak_perf_for_type

# --- Generic Roofline Plotting Function ---
def plot_roofline_generic(fig, ax, title, workload_data_list, show_1d_roofline=True):
    """
    Generates a roofline plot on the given axes within the provided figure.

    Args:
        fig (matplotlib.figure.Figure): The figure object.
        ax (matplotlib.axes.Axes): The axes object to draw on.
        title (str): The title for the plot.
        workload_data_list (list): A list of dictionaries for workloads.
        show_1d_roofline (bool): Whether to plot the 1D PE array roofline.
    """
    oi_min_plot = 0.01
    oi_max_plot = 30000 # Adjusted max OI slightly
    perf_min_plot = 10
    
    # Determine max performance limit based on whether 1D roof is shown
    perf_max_roof_limit = PEAK_PERF_2D_GFLOPS
    if show_1d_roofline:
        perf_max_roof_limit = max(PEAK_PERF_1D_GFLOPS, PEAK_PERF_2D_GFLOPS)
    perf_max_plot_limit = perf_max_roof_limit * 1.5 # Add some headroom

    # Determine OI range based on plotted points and ridge points
    all_ois_for_range = [oi_min_plot, oi_max_plot, RIDGE_POINT_2D]
    if show_1d_roofline:
        all_ois_for_range.append(RIDGE_POINT_1D)
        
    for wl_data in workload_data_list:
        # Ensure 'flops' and 'bytes' keys exist and are positive before calculating OI
        if wl_data.get('bytes', 0) > 0 and wl_data.get('flops', 0) > 0:
            all_ois_for_range.append(wl_data['flops'] / wl_data['bytes'])
    
    # Filter out non-positive values before creating the range
    positive_ois = [oi for oi in all_ois_for_range if oi > 0]
    if not positive_ois: # Handle case where no valid OIs exist
         oi_range = np.array([oi_min_plot, oi_max_plot])
    else:
        oi_range = np.array(sorted(list(set(positive_ois))))
        # Ensure the range covers the min/max plot limits if needed
        oi_range = np.union1d(oi_range, [oi for oi in [oi_min_plot, oi_max_plot] if oi > 0])
        oi_range = oi_range[(oi_range >= oi_min_plot) & (oi_range <= oi_max_plot)]
        if len(oi_range) < 2 : 
            # Ensure at least two points for plotting lines if filtering is aggressive
             oi_range = np.array([min(positive_ois) if positive_ois else oi_min_plot, 
                                 max(positive_ois) if positive_ois else oi_max_plot])


    # Plot 2D Roofline (always shown)
    roofline_perf_2d = np.minimum(PEAK_PERF_2D_GFLOPS, oi_range * MEM_BANDWIDTH_GB_s)
    ax.plot(oi_range, roofline_perf_2d, label=f'2D PE Array Roof (Peak: {PEAK_PERF_2D_GFLOPS/1000:.1f} TFLOPs/s)', color='black', linestyle='-', linewidth=2.5) # Increased linewidth

    # Plot 1D Roofline (conditional)
    if show_1d_roofline:
        roofline_perf_1d = np.minimum(PEAK_PERF_1D_GFLOPS, oi_range * MEM_BANDWIDTH_GB_s) 
        ax.plot(oi_range, roofline_perf_1d, label=f'1D PE Array Roof (Peak: {PEAK_PERF_1D_GFLOPS:.0f} GFLOPs/s)', color='dimgray', linestyle='--', linewidth=2.5) # Increased linewidth

    # Plot workload points
    plotted_ois = []
    plotted_perfs = []

    for wl_data in workload_data_list:
        flops = wl_data.get('flops', 0) # Use .get for safety
        bytes_val = wl_data.get('bytes', 0)
        
        if bytes_val <= 0 or flops <=0: 
            continue

        oi = flops / bytes_val
        pe_type = wl_data.get('pe_type', 'unknown') # Use .get for safety
        
        achieved_perf = 0
        if pe_type == '2d':
            achieved_perf = get_achieved_perf(oi, PEAK_PERF_2D_GFLOPS, MEM_BANDWIDTH_GB_s, RIDGE_POINT_2D)
        elif pe_type == '1d':
            if show_1d_roofline:
                achieved_perf = get_achieved_perf(oi, PEAK_PERF_1D_GFLOPS, MEM_BANDWIDTH_GB_s, RIDGE_POINT_1D)
            else:
                continue 
        else:
            continue
        
        if oi > 0 and achieved_perf > 0:
            # Use larger markersize and add edge
            ax.plot(oi, achieved_perf, marker=wl_data.get('marker', 'o'), markersize=11, linestyle='None', 
                    label=f"{wl_data.get('label','Unknown')} ({pe_type.upper()})", color=wl_data.get('color', 'blue'), 
                    markeredgewidth=0.8, markeredgecolor='black') 
            plotted_ois.append(oi)
            plotted_perfs.append(achieved_perf)

    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Operational Intensity (FLOPs/Byte)')
    ax.set_ylabel('Performance (GFLOPs/s)')
    ax.set_title(title)
    
    # Adjust plot limits
    current_oi_min = oi_min_plot
    current_oi_max = oi_max_plot
    current_perf_min = perf_min_plot
    current_perf_max = perf_max_plot_limit # Use limit determined by rooflines shown

    # Refine limits based on plotted data
    if plotted_ois: 
        # Add buffer based on log scale
        log_oi_min = np.log10(min(plotted_ois))
        log_oi_max = np.log10(max(plotted_ois))
        # Ensure min/max are valid before log
        current_oi_min = min(oi_min_plot, 10**(log_oi_min - (log_oi_max - log_oi_min) * 0.1)) if min(plotted_ois) > 0 else oi_min_plot
        current_oi_max = max(oi_max_plot, 10**(log_oi_max + (log_oi_max - log_oi_min) * 0.2)) if max(plotted_ois) > 0 else oi_max_plot
    if plotted_perfs:
        log_perf_min = np.log10(min(plotted_perfs))
        log_perf_max = np.log10(max(plotted_perfs))
        current_perf_min = min(perf_min_plot, 10**(log_perf_min - (log_perf_max - log_perf_min) * 0.1)) if min(plotted_perfs) > 0 else perf_min_plot
        # Ensure upper limit includes the relevant peak performance
        peak_to_consider = PEAK_PERF_2D_GFLOPS if not show_1d_roofline else max(PEAK_PERF_1D_GFLOPS, PEAK_PERF_2D_GFLOPS)
        current_perf_max = max(peak_to_consider * 1.5, 10**(log_perf_max + (log_perf_max - log_perf_min) * 0.2)) if max(plotted_perfs) > 0 else perf_max_plot_limit

    ax.set_xlim(current_oi_min, current_oi_max)
    ax.set_ylim(current_perf_min, current_perf_max)
    
    # Adjust legend font size and columns based on number of items
    handles, labels = ax.get_legend_handles_labels()
    num_items = len(handles)
    legend_cols = 1 if num_items <= 6 else 2 # Fewer items per column for larger font
    legend_fontsize = plt.rcParams['legend.fontsize'] # Use global setting
    if num_items > 12: # Reduce further if very crowded
         legend_fontsize -= 2
    
    ax.legend(handles=handles, labels=labels, fontsize=legend_fontsize, loc='lower right', ncol=legend_cols, framealpha=0.8) 
    ax.grid(True, which="both", ls="--", alpha=0.4, color='gray') # Lighter grid


# --- Helper function to calculate FLOPs and Bytes for Transformer Components (FuseMax with SRAM constraint) ---
def calculate_transformer_layer_components_fusemax(model_prefix, n_seq, d_model, n_heads, d_ff, 
                                                 attn_color='red', mlp_color='green', overall_color='blue',
                                                 attn_marker='o', mlp_marker='o', overall_marker='D'):
    """Calculates FLOPs and Bytes for Attn, MLP, and Overall Layer (FuseMax),
       considering SRAM capacity for weights and allowing custom styling."""
    # --- [Calculation logic remains the same as previous version] ---
    d_head = d_model // n_heads
    components = []
    debug_prints = False # Set to True to see SRAM penalty messages

    # 1. Attention Core (FuseMax)
    flops_qk_av_per_head = 2 * (n_seq**2 * d_head)
    flops_softmax_per_head = 3 * (n_seq**2)
    total_flops_core_attn = n_heads * (flops_qk_av_per_head * 2 + flops_softmax_per_head)
    bytes_core_attn = (4 * n_seq * d_model) * BYTES_PER_ELEMENT_BF16
    components.append({
        'label': f'{model_prefix} Attn', 'flops': total_flops_core_attn, 'bytes': bytes_core_attn,
        'pe_type': '2d', 'color': attn_color, 'marker': attn_marker
    })
    
    # 2. MLP (FuseMax)
    flops_gemm1_mlp = 2 * n_seq * d_ff * d_model
    flops_activation_mlp = GELU_FLOPS_PER_ELEMENT * n_seq * d_ff
    flops_gemm2_mlp = 2 * n_seq * d_model * d_ff
    total_flops_mlp = flops_gemm1_mlp + flops_activation_mlp + flops_gemm2_mlp
    
    mlp_gemm1_weight_bytes = d_model * d_ff * BYTES_PER_ELEMENT_BF16
    mlp_gemm2_weight_bytes = d_ff * d_model * BYTES_PER_ELEMENT_BF16
    
    adjusted_mlp_gemm1_w_bytes = mlp_gemm1_weight_bytes
    if mlp_gemm1_weight_bytes > SRAM_CAPACITY_BYTES:
        penalty_factor1 = mlp_gemm1_weight_bytes / SRAM_CAPACITY_BYTES
        adjusted_mlp_gemm1_w_bytes = mlp_gemm1_weight_bytes * penalty_factor1
        if debug_prints: print(f"INFO: {model_prefix} MLP GEMM1 weights ({mlp_gemm1_weight_bytes/1024/1024:.2f}MB) exceed SRAM ({SRAM_CAPACITY_BYTES/1024/1024:.2f}MB). Penalty: {penalty_factor1:.2f}x")

    adjusted_mlp_gemm2_w_bytes = mlp_gemm2_weight_bytes
    if mlp_gemm2_weight_bytes > SRAM_CAPACITY_BYTES:
        penalty_factor2 = mlp_gemm2_weight_bytes / SRAM_CAPACITY_BYTES
        adjusted_mlp_gemm2_w_bytes = mlp_gemm2_weight_bytes * penalty_factor2
        if debug_prints: print(f"INFO: {model_prefix} MLP GEMM2 weights ({mlp_gemm2_weight_bytes/1024/1024:.2f}MB) exceed SRAM ({SRAM_CAPACITY_BYTES/1024/1024:.2f}MB). Penalty: {penalty_factor2:.2f}x")

    bytes_mlp_weights_total_adjusted = adjusted_mlp_gemm1_w_bytes + adjusted_mlp_gemm2_w_bytes
    bytes_mlp_activations = ( (n_seq * d_model) + (n_seq * d_model) ) * BYTES_PER_ELEMENT_BF16
    bytes_mlp = bytes_mlp_activations + bytes_mlp_weights_total_adjusted
    
    components.append({
        'label': f'{model_prefix} MLP', 'flops': total_flops_mlp, 'bytes': bytes_mlp,
        'pe_type': '2d', 'color': mlp_color, 'marker': mlp_marker
    })

    # 3. Overall Layer (FuseMax)
    flops_attn_projections = 4 * (2 * n_seq * d_model**2) 
    flops_layernorm_op = LAYERNORM_FLOPS_PER_ELEMENT * n_seq * d_model
    total_flops_overall = flops_attn_projections + total_flops_core_attn + total_flops_mlp + 2 * flops_layernorm_op
    
    one_attn_proj_weight_bytes = (d_model**2) * BYTES_PER_ELEMENT_BF16
    adjusted_one_attn_proj_w_bytes = one_attn_proj_weight_bytes
    if one_attn_proj_weight_bytes > SRAM_CAPACITY_BYTES:
        penalty_factor_attn = one_attn_proj_weight_bytes / SRAM_CAPACITY_BYTES
        adjusted_one_attn_proj_w_bytes = one_attn_proj_weight_bytes * penalty_factor_attn
        if debug_prints: print(f"INFO: {model_prefix} Attn Proj weights ({one_attn_proj_weight_bytes/1024/1024:.2f}MB per proj) exceed SRAM ({SRAM_CAPACITY_BYTES/1024/1024:.2f}MB). Penalty: {penalty_factor_attn:.2f}x")

    bytes_overall_weights_attn_proj_adjusted = adjusted_one_attn_proj_w_bytes * 4
    bytes_overall_activations = (2 * n_seq * d_model) * BYTES_PER_ELEMENT_BF16
    total_bytes_overall = bytes_overall_activations + bytes_overall_weights_attn_proj_adjusted + bytes_mlp_weights_total_adjusted
    
    components.append({
        'label': f'{model_prefix} Overall', 'flops': total_flops_overall, 'bytes': total_bytes_overall,
        'pe_type': '2d', 'color': overall_color, 'marker': overall_marker
    })
    return components

# --- Data Preparation for Plot 1: BERT Component Operations & Baselines ---
workloads_for_plot1 = []
bert_components_fusemax = calculate_transformer_layer_components_fusemax(
    "BERT", N_SEQ_REF_BERT, D_MODEL_BERT, N_HEADS_BERT, D_FF_BERT,
    attn_color='firebrick', mlp_color='forestgreen', overall_color='royalblue', 
    attn_marker='o', mlp_marker='o', overall_marker='D'
)
bert_attn_fusemax_data = next(c for c in bert_components_fusemax if "Attn" in c["label"])
bert_mlp_fusemax_data = next(c for c in bert_components_fusemax if "MLP" in c["label"])
bert_overall_fusemax_data = next(c for c in bert_components_fusemax if "Overall" in c["label"])

workloads_for_plot1.append({**bert_attn_fusemax_data, 'label': 'Attn (FuseMax-BERT)'})
workloads_for_plot1.append({**bert_mlp_fusemax_data, 'label': 'MLP (FuseMax-BERT)'})
workloads_for_plot1.append({**bert_overall_fusemax_data, 'label': 'Overall (FuseMax-BERT)'})

bytes_core_attn_unfused_bert = bert_attn_fusemax_data['bytes'] * 2.5
workloads_for_plot1.append({
    'label': 'Attn (Unfused-BERT)', 'flops': bert_attn_fusemax_data['flops'], 'bytes': bytes_core_attn_unfused_bert,
    'pe_type': '2d', 'color': 'darkorange', 'marker': 'X' 
})
mlp_activation_bytes_bert_unfused = ( (N_SEQ_REF_BERT * D_MODEL_BERT) + 
                                (N_SEQ_REF_BERT * D_FF_BERT) * 4 + 
                                (N_SEQ_REF_BERT * D_MODEL_BERT)   
                              ) * BYTES_PER_ELEMENT_BF16
mlp_weight_bytes_bert_unfused = ( (D_MODEL_BERT * D_FF_BERT) + (D_FF_BERT * D_MODEL_BERT) ) * BYTES_PER_ELEMENT_BF16 
bytes_mlp_unfused_bert = mlp_activation_bytes_bert_unfused + mlp_weight_bytes_bert_unfused
workloads_for_plot1.append({
    'label': 'MLP (Unfused-BERT)', 'flops': bert_mlp_fusemax_data['flops'], 'bytes': bytes_mlp_unfused_bert,
    'pe_type': '2d', 'color': 'gold', 'marker': 'X' 
})
bytes_core_attn_flat_bert = bert_attn_fusemax_data['bytes'] * 1.75
workloads_for_plot1.append({
    'label': 'Attn (FLAT-BERT)', 'flops': bert_attn_fusemax_data['flops'], 'bytes': bytes_core_attn_flat_bert,
    'pe_type': '2d', 'color': 'lightcoral', 'marker': 'P' 
})
bytes_mlp_flat_bert = (bert_mlp_fusemax_data['bytes'] + bytes_mlp_unfused_bert) / 2.2 
workloads_for_plot1.append({
    'label': 'MLP (FLAT-BERT)', 'flops': bert_mlp_fusemax_data['flops'], 'bytes': bytes_mlp_flat_bert,
    'pe_type': '2d', 'color': 'yellowgreen', 'marker': 'P' 
})

# Add 1D operations ONLY to Plot 1
flops_softmax_1d_bert = 3 * (N_SEQ_REF_BERT**2) 
bytes_softmax_1d_bert = (N_SEQ_REF_BERT**2 * BYTES_PER_ELEMENT_BF16) * 2 
workloads_for_plot1.append({'label': 'Softmax (1D)', 'flops': flops_softmax_1d_bert * N_HEADS_BERT, 'bytes': bytes_softmax_1d_bert * N_HEADS_BERT, 'pe_type': '1d', 'color': 'magenta', 'marker': 's'})
flops_gelu_1d_bert = GELU_FLOPS_PER_ELEMENT * N_SEQ_REF_BERT * D_FF_BERT
bytes_gelu_1d_bert = (N_SEQ_REF_BERT * D_FF_BERT * BYTES_PER_ELEMENT_BF16) * 2
workloads_for_plot1.append({'label': 'GELU (1D)', 'flops': flops_gelu_1d_bert, 'bytes': bytes_gelu_1d_bert, 'pe_type': '1d', 'color': 'cyan', 'marker': 's'})
flops_layernorm_1d_bert = LAYERNORM_FLOPS_PER_ELEMENT * N_SEQ_REF_BERT * D_MODEL_BERT
bytes_layernorm_1d_bert = (N_SEQ_REF_BERT * D_MODEL_BERT * BYTES_PER_ELEMENT_BF16) * 2
workloads_for_plot1.append({'label': 'LayerNorm (1D)', 'flops': flops_layernorm_1d_bert, 'bytes': bytes_layernorm_1d_bert, 'pe_type': '1d', 'color': 'orange', 'marker': 's'})

# --- Data Preparation for Plot 2: BERT Overall Layer (Varying Sequence Lengths) ---
workloads_for_plot2 = []
seq_length_configs_plot2 = [
    {'label_suffix': 'N_seq=256 (Short)', 'N': 256, 'color': 'darkviolet', 'marker':'P'}, # Changed N back to 256
    {'label_suffix': f'N_seq={N_SEQ_REF_BERT} (Medium)', 'N': N_SEQ_REF_BERT, 'color': 'royalblue', 'marker':'D'},
    {'label_suffix': 'N_seq=4096 (Long)', 'N': 4096, 'color': 'saddlebrown', 'marker':'X'} 
]
for config in seq_length_configs_plot2:
    n_seq = config['N']
    bert_overall_components = calculate_transformer_layer_components_fusemax(
        "BERT", n_seq, D_MODEL_BERT, N_HEADS_BERT, D_FF_BERT,
        overall_color=config['color'], overall_marker=config['marker'] 
    )
    overall_data = next(c for c in bert_overall_components if "Overall" in c["label"])
    workloads_for_plot2.append({
        **overall_data, 'label': f'BERT Overall ({config["label_suffix"]})'
    })
# DO NOT add 1D ops to Plot 2

# --- Data Preparation for Plot 3: OPT & Pythia Components (FuseMax, N_SEQ_REF_OTHERS) ---
N_SEQ_REF_OTHERS = 2048 
workloads_for_plot3 = []
opt_components = calculate_transformer_layer_components_fusemax(
    "OPT", N_SEQ_REF_OTHERS, D_MODEL_OPT, N_HEADS_OPT, D_FF_OPT,
    attn_color='purple', mlp_color='orange', overall_color='red',
    attn_marker='o', mlp_marker='o', overall_marker='D' 
)
workloads_for_plot3.extend(opt_components)

pythia_components = calculate_transformer_layer_components_fusemax(
    "Pythia", N_SEQ_REF_OTHERS, D_MODEL_PYTHIA, N_HEADS_PYTHIA, D_FF_PYTHIA,
    attn_color='green', mlp_color='indigo', overall_color='yellow',
    attn_marker='^', mlp_marker='^', overall_marker='P' 
)
workloads_for_plot3.extend(pythia_components)
# DO NOT add 1D ops to Plot 3

# --- Data Preparation for Plot 4: Overall Performance (BERT, OPT, Pythia - Varying Contexts) ---
workloads_for_plot4 = []
seq_length_configs_plot4 = [
    {'label_suffix': 'N_seq=256 (Short)', 'N': 256, 'marker': 'P'}, # Changed N back to 256
    {'label_suffix': 'N_seq=4096 (Long)', 'N': 4096, 'marker': 'D'}
]
model_configs_plot4 = [
    {'prefix': 'BERT', 'd_model': D_MODEL_BERT, 'n_heads': N_HEADS_BERT, 'd_ff': D_FF_BERT, 'color': 'royalblue'},
    {'prefix': 'OPT', 'd_model': D_MODEL_OPT, 'n_heads': N_HEADS_OPT, 'd_ff': D_FF_OPT, 'color': 'indigo'},
    {'prefix': 'Pythia', 'd_model': D_MODEL_PYTHIA, 'n_heads': N_HEADS_PYTHIA, 'd_ff': D_FF_PYTHIA, 'color': 'darkslategray'}
]

for model_cfg in model_configs_plot4:
    for seq_cfg in seq_length_configs_plot4:
        n_seq = seq_cfg['N']
        components = calculate_transformer_layer_components_fusemax(
            model_cfg['prefix'], n_seq, model_cfg['d_model'], model_cfg['n_heads'], model_cfg['d_ff'],
            overall_color=model_cfg['color'], overall_marker=seq_cfg['marker']
        )
        overall_data = next(c for c in components if "Overall" in c["label"])
        workloads_for_plot4.append({
            **overall_data,
            'label': f'{model_cfg["prefix"]} Overall ({seq_cfg["label_suffix"]})'
        })
# DO NOT add 1D ops to Plot 4

# --- Create and Save Figures ---

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Plot 1
fig1, ax1 = plt.subplots(figsize=(10, 8)) # Adjust figsize as needed
plot_roofline_generic(fig1, ax1, f'Plot 1: BERT Component Ops & Baselines (N_seq={N_SEQ_REF_BERT})', workloads_for_plot1, show_1d_roofline=True) 
fig1.savefig(os.path.join(output_dir, "roofline_plot_1_bert_baselines.jpeg"), bbox_inches='tight')
plt.close(fig1) # Close figure to free memory

# Plot 2
fig2, ax2 = plt.subplots(figsize=(10, 8))
plot_roofline_generic(fig2, ax2, 'Plot 2: BERT Overall Layer - FuseMax (Varying Seq Length)', workloads_for_plot2, show_1d_roofline=False) 
fig2.savefig(os.path.join(output_dir, "roofline_plot_2_bert_varying_seq.jpeg"), bbox_inches='tight')
plt.close(fig2)

# Plot 3
fig3, ax3 = plt.subplots(figsize=(10, 8))
plot_roofline_generic(fig3, ax3, f'Plot 3: OPT & Pythia Components - FuseMax (N_seq={N_SEQ_REF_OTHERS}, SRAM Constraint)', workloads_for_plot3, show_1d_roofline=False) 
fig3.savefig(os.path.join(output_dir, "roofline_plot_3_opt_pythia_components.jpeg"), bbox_inches='tight')
plt.close(fig3)

# Plot 4
fig4, ax4 = plt.subplots(figsize=(10, 8))
plot_roofline_generic(fig4, ax4, 'Plot 4: Model Overall Layer - FuseMax (Varying Seq Length, SRAM Constraint)', workloads_for_plot4, show_1d_roofline=False) 
fig4.savefig(os.path.join(output_dir, "roofline_plot_4_overall_comparison.jpeg"), bbox_inches='tight')
plt.close(fig4)

print(f"Roofline plots saved to directory: {output_dir}")

# Optionally show plots in notebook if needed (usually not needed if saving)
# plt.show() 

# --- Output calculated values for verification (Optional) ---
print_output = True # Set to False to disable printouts
if print_output:
    print("\n--- System & Roofline Parameters ---")
 
    print(f"Memory Bandwidth: {MEM_BANDWIDTH_GB_s} GB/s")
    print(f"2D PE Array: {PE_ROWS_2D}x{PE_COLS_2D} PEs")
    print(f"  Peak Performance (2D): {PEAK_PERF_2D_GFLOPS:.2f} GFLOPs/s ({PEAK_PERF_2D_GFLOPS/1000:.2f} TFLOPs/s)")
    print(f"  Ridge Point (2D): {RIDGE_POINT_2D:.2f} FLOPs/Byte")
    print(f"1D PE Array: 1x{NUM_PES_1D} PEs")
    print(f"  Peak Performance (1D): {PEAK_PERF_1D_GFLOPS:.2f} GFLOPs/s")
    print(f"  Ridge Point (1D): {RIDGE_POINT_1D:.2f} FLOPs/Byte")

    all_plots_data = {
        f"Plot 1 (BERT Components, N_seq={N_SEQ_REF_BERT})": workloads_for_plot1,
        "Plot 2 (BERT Overall, Varying N_seq)": workloads_for_plot2,
        f"Plot 3 (OPT/Pythia Components, N_seq={N_SEQ_REF_OTHERS})": workloads_for_plot3,
        "Plot 4 (All Models Overall, Varying N_seq)": workloads_for_plot4,
    }

    for plot_name, workloads in all_plots_data.items():
        print(f"\n--- Workloads for {plot_name} ---")
        for wl in workloads:
            oi = 0
            if wl.get('bytes', 0) > 0 and wl.get('flops', 0) > 0:
                oi = wl['flops'] / wl['bytes']
            
            peak_p = PEAK_PERF_2D_GFLOPS if wl['pe_type']=='2d' else PEAK_PERF_1D_GFLOPS
            ridge_p = RIDGE_POINT_2D if wl['pe_type']=='2d' else RIDGE_POINT_1D
            perf = get_achieved_perf(oi, peak_p, MEM_BANDWIDTH_GB_s, ridge_p)
            print(f"  {wl['label']:<45} ({wl['pe_type']}): FLOPs={wl['flops']:.2e}, Bytes={wl['bytes']:.2e}, OI={oi:.2f}, Est. Perf={perf/1000 if perf >=1000 else perf:.1f} {'TFLOPs/s' if perf >=1000 else 'GFLOPs/s'}")
# Out:
# Roofline plots saved to directory: ./roofline_plots
#
# --- System & Roofline Parameters ---
# Memory Bandwidth: 400 GB/s
# 2D PE Array: 256x256 PEs
#   Peak Performance (2D): 123207.68 GFLOPs/s (123.21 TFLOPs/s)
#   Ridge Point (2D): 308.02 FLOPs/Byte
# 1D PE Array: 1x256 PEs
#   Peak Performance (1D): 481.28 GFLOPs/s
#   Ridge Point (1D): 1.20 FLOPs/Byte
#
# --- Workloads for Plot 1 (BERT Components, N_seq=1024) ---
#   Attn (FuseMax-BERT)                           (2d): FLOPs=4.35e+09, Bytes=8.39e+06, OI=518.00, Est. Perf=123.2 TFLOPs/s
#   MLP (FuseMax-BERT)                            (2d): FLOPs=1.72e+10, Bytes=3.77e+07, OI=456.22, Est. Perf=123.2 TFLOPs/s
#   Overall (FuseMax-BERT)                        (2d): FLOPs=3.02e+10, Bytes=4.61e+07, OI=653.86, Est. Perf=123.2 TFLOPs/s
#   Attn (Unfused-BERT)                           (2d): FLOPs=4.35e+09, Bytes=2.10e+07, OI=207.20, Est. Perf=82.9 TFLOPs/s
#   MLP (Unfused-BERT)                            (2d): FLOPs=1.72e+10, Bytes=5.45e+07, OI=315.85, Est. Perf=123.2 TFLOPs/s
#   Attn (FLAT-BERT)                              (2d): FLOPs=4.35e+09, Bytes=1.47e+07, OI=296.00, Est. Perf=118.4 TFLOPs/s
#   MLP (FLAT-BERT)                               (2d): FLOPs=1.72e+10, Bytes=4.19e+07, OI=410.60, Est. Perf=123.2 TFLOPs/s
#   Softmax (1D)                                  (1d): FLOPs=5.03e+07, Bytes=6.71e+07, OI=0.75, Est. Perf=300.0 GFLOPs/s
#   GELU (1D)                                     (1d): FLOPs=4.19e+07, Bytes=1.68e+07, OI=2.50, Est. Perf=481.3 GFLOPs/s
#   LayerNorm (1D)                                (1d): FLOPs=5.24e+06, Bytes=4.19e+06, OI=1.25, Est. Perf=481.3 GFLOPs/s
#
# --- Workloads for Plot 2 (BERT Overall, Varying N_seq) ---
#   BERT Overall (N_seq=256 (Short))              (2d): FLOPs=6.73e+09, Bytes=4.30e+07, OI=156.48, Est. Perf=62.6 TFLOPs/s
#   BERT Overall (N_seq=1024 (Medium))            (2d): FLOPs=3.02e+10, Bytes=4.61e+07, OI=653.86, Est. Perf=123.2 TFLOPs/s
#   BERT Overall (N_seq=4096 (Long))              (2d): FLOPs=1.73e+11, Bytes=5.87e+07, OI=2943.00, Est. Perf=123.2 TFLOPs/s
#
# --- Workloads for Plot 3 (OPT/Pythia Components, N_seq=2048) ---
#   OPT Attn                                      (2d): FLOPs=1.56e+11, Bytes=1.51e+08, OI=1030.00, Est. Perf=123.2 TFLOPs/s
#   OPT MLP                                       (2d): FLOPs=2.78e+12, Bytes=2.20e+11, OI=12.64, Est. Perf=5.1 TFLOPs/s
#   OPT Overall                                   (2d): FLOPs=4.33e+12, Bytes=2.48e+11, OI=17.48, Est. Perf=7.0 TFLOPs/s
#   Pythia Attn                                   (2d): FLOPs=2.20e+09, Bytes=2.10e+06, OI=1048.00, Est. Perf=123.2 TFLOPs/s
#   Pythia MLP                                    (2d): FLOPs=5.47e+08, Bytes=1.31e+06, OI=417.60, Est. Perf=123.2 TFLOPs/s
#   Pythia Overall                                (2d): FLOPs=3.02e+09, Bytes=1.44e+06, OI=2092.00, Est. Perf=123.2 TFLOPs/s
#
# --- Workloads for Plot 4 (All Models Overall, Varying N_seq) ---
#   BERT Overall (N_seq=256 (Short))              (2d): FLOPs=6.73e+09, Bytes=4.30e+07, OI=156.48, Est. Perf=62.6 TFLOPs/s
#   BERT Overall (N_seq=4096 (Long))              (2d): FLOPs=1.73e+11, Bytes=5.87e+07, OI=2943.00, Est. Perf=123.2 TFLOPs/s
#   OPT Overall (N_seq=256 (Short))               (2d): FLOPs=5.24e+11, Bytes=2.48e+11, OI=2.12, Est. Perf=846.9 GFLOPs/s
#   OPT Overall (N_seq=4096 (Long))               (2d): FLOPs=8.97e+12, Bytes=2.48e+11, OI=36.21, Est. Perf=14.5 TFLOPs/s
#   Pythia Overall (N_seq=256 (Short))            (2d): FLOPs=1.37e+08, Bytes=5.24e+05, OI=260.62, Est. Perf=104.2 TFLOPs/s
#   Pythia Overall (N_seq=4096 (Long))            (2d): FLOPs=1.04e+10, Bytes=2.49e+06, OI=4187.37, Est. Perf=123.2 TFLOPs/s

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Although pandas is imported, it's not used in this version. Kept for potential future use.
import os
import math # For log/pow calculations

# --- Plotting Style Configuration ---
# Define base font size for consistent styling across plots
font_size_base = 14 
plt.rcParams.update({
    'font.size': font_size_base,
    'axes.titlesize': font_size_base + 2,
    'axes.labelsize': font_size_base,
    'xtick.labelsize': font_size_base - 2,
    'ytick.labelsize': font_size_base - 2,
    'legend.fontsize': font_size_base - 4, # Base legend size, adjusted dynamically later
    'figure.titlesize': font_size_base + 4 
})
# Define the directory where plots will be saved
output_dir = "./roofline_plots"

# --- System Parameters (Global for this hardware configuration) ---
# Define key hardware performance characteristics
MEM_BANDWIDTH_GB_s = 400  # Main memory bandwidth in GB/s
CLOCK_FREQ_MHZ = 940      # Accelerator clock frequency in MHz
FLOPS_PER_PE_PER_CYCLE = 2 # Floating point operations per PE per clock cycle
SRAM_CAPACITY_BYTES = 4 * 1024 * 1024 # 4MB Shared Global Buffer from arch-2d.yaml

# 2D PE Array configuration
PE_ROWS_2D = 256
PE_COLS_2D = 256
NUM_PES_2D = PE_ROWS_2D * PE_COLS_2D # Total number of PEs in the 2D array

# 1D PE Array configuration (Vector unit)
NUM_PES_1D = 256 # Total number of PEs in the 1D array (e.g., 1x256)

# --- Calculate Peak Performance (GFLOPs/s) ---
# Calculate the theoretical peak performance for both PE arrays
PEAK_PERF_2D_GFLOPS = (NUM_PES_2D * FLOPS_PER_PE_PER_CYCLE * CLOCK_FREQ_MHZ) / 1000
PEAK_PERF_1D_GFLOPS = (NUM_PES_1D * FLOPS_PER_PE_PER_CYCLE * CLOCK_FREQ_MHZ) / 1000

# --- Calculate Roofline Ridge Points (FLOPs/Byte) ---
# The ridge point is the operational intensity where performance transitions
# from memory-bound to compute-bound. OI = Peak Perf / Memory Bandwidth.
RIDGE_POINT_2D = PEAK_PERF_2D_GFLOPS / MEM_BANDWIDTH_GB_s
RIDGE_POINT_1D = PEAK_PERF_1D_GFLOPS / MEM_BANDWIDTH_GB_s

# --- Workload Model Parameters ---
# Define parameters for different Transformer models used in the plots
# BERT-Large like (Plot 1 & 2)
N_SEQ_REF_BERT = 1024       # Reference sequence length for BERT component plot
D_MODEL_BERT = 1024         # Hidden dimension
N_HEADS_BERT = 16           # Number of attention heads
D_HEAD_BERT = D_MODEL_BERT // N_HEADS_BERT # Dimension per head
D_FF_BERT = D_MODEL_BERT * 4 # Feed-forward inner dimension

# Pythia-14M (Plot 3 & 4)
N_SEQ_REF_PYTHIA = 2048     # Reference sequence length for component plot
D_MODEL_PYTHIA = 128
N_HEADS_PYTHIA = 4
D_HEAD_PYTHIA = D_MODEL_PYTHIA // N_HEADS_PYTHIA
D_FF_PYTHIA = D_MODEL_PYTHIA * 4 # Standard FFN expansion factor

# OPT-66B (Plot 3 & 4)
N_SEQ_REF_OPT = 2048        # Reference sequence length for component plot
D_MODEL_OPT = 9216
N_HEADS_OPT = 72
D_HEAD_OPT = D_MODEL_OPT // N_HEADS_OPT
D_FF_OPT = 36864            # Explicit FFN dimension from config

# Common parameters
BYTES_PER_ELEMENT_BF16 = 2  # Assuming BF16 data type (2 bytes)
GELU_FLOPS_PER_ELEMENT = 10 # Approximate FLOPs for GELU activation
LAYERNORM_FLOPS_PER_ELEMENT = 5 # Approximate FLOPs for Layer Normalization

# --- Helper function to calculate achieved performance ---
def get_achieved_perf(oi, peak_perf_for_type, bandwidth, ridge_point_for_type):
    """
    Calculates achieved performance based on Operational Intensity (OI) 
    for a specific roofline model.

    Args:
        oi (float): Operational Intensity (FLOPs/Byte).
        peak_perf_for_type (float): Peak performance (GFLOPs/s) of the relevant PE array.
        bandwidth (float): Memory bandwidth (GB/s, numerically equivalent to GBytes/s).
        ridge_point_for_type (float): The ridge point (FLOPs/Byte) for the relevant PE array.

    Returns:
        float: Estimated achieved performance (GFLOPs/s). Returns 0 if OI is non-positive.
    """
    if oi <= 0: 
        return 0 # Performance is zero if OI is not positive
    # Performance is limited by bandwidth for low OI (memory-bound)
    # Performance is limited by peak compute for high OI (compute-bound)
    if oi < ridge_point_for_type:
        return oi * bandwidth
    else:
        return peak_perf_for_type

# --- Generic Roofline Plotting Function ---
def plot_roofline_generic(fig, ax, title, workload_data_list, show_1d_roofline=True, fixed_xlim=None, fixed_ylim=None):
    """
    Generates a roofline plot on the given axes within the provided figure,
    optionally using fixed axis limits.

    Args:
        fig (matplotlib.figure.Figure): The figure object.
        ax (matplotlib.axes.Axes): The axes object to draw on.
        title (str): The title for the plot.
        workload_data_list (list): A list of dictionaries for workloads. Each dict should contain
                                   'label', 'flops', 'bytes', 'pe_type', 'color', 'marker'.
        show_1d_roofline (bool): Whether to plot the 1D PE array roofline and 1D points.
        fixed_xlim (tuple, optional): A tuple (min, max) for the x-axis limits. If None, limits are dynamic.
        fixed_ylim (tuple, optional): A tuple (min, max) for the y-axis limits. If None, limits are dynamic.
    """
    # Define default plot boundaries (used if dynamic limits are needed)
    oi_min_plot_default = 0.01
    oi_max_plot_default = 30000 
    perf_min_plot_default = 10
    
    # Determine max performance roof limit based on whether 1D roof is shown
    perf_max_roof_limit = PEAK_PERF_2D_GFLOPS
    if show_1d_roofline:
        perf_max_roof_limit = max(PEAK_PERF_1D_GFLOPS, PEAK_PERF_2D_GFLOPS)
    perf_max_plot_limit_default = perf_max_roof_limit * 1.5 # Default headroom

    # Determine OI range for drawing the roofline curves
    # Include default limits and ridge points
    all_ois_for_range = [oi_min_plot_default, oi_max_plot_default, RIDGE_POINT_2D]
    if show_1d_roofline:
        all_ois_for_range.append(RIDGE_POINT_1D)
        
    # Add OIs from the actual workload data
    for wl_data in workload_data_list:
        if wl_data.get('bytes', 0) > 0 and wl_data.get('flops', 0) > 0:
            all_ois_for_range.append(wl_data['flops'] / wl_data['bytes'])
    
    # Filter out non-positive values and create sorted unique OI range
    positive_ois = [oi for oi in all_ois_for_range if oi > 0]
    if not positive_ois: 
         oi_range = np.array([oi_min_plot_default, oi_max_plot_default]) # Fallback if no valid OIs
    else:
        oi_range = np.array(sorted(list(set(positive_ois))))
        # Ensure the range covers the min/max plot limits if needed
        oi_range = np.union1d(oi_range, [oi for oi in [oi_min_plot_default, oi_max_plot_default] if oi > 0])
        # Clip range to default boundaries if they were exceeded by data points
        oi_range = oi_range[(oi_range >= oi_min_plot_default) & (oi_range <= oi_max_plot_default)]
        if len(oi_range) < 2 : 
             # Ensure at least two points for plotting lines if filtering is aggressive
             oi_range = np.array([min(positive_ois) if positive_ois else oi_min_plot_default, 
                                 max(positive_ois) if positive_ois else oi_max_plot_default])

    # --- Plot Rooflines ---
    # Plot 2D Roofline (always shown)
    roofline_perf_2d = np.minimum(PEAK_PERF_2D_GFLOPS, oi_range * MEM_BANDWIDTH_GB_s)
    ax.plot(oi_range, roofline_perf_2d, label=f'2D PE Array Roof (Peak: {PEAK_PERF_2D_GFLOPS/1000:.1f} TFLOPs/s)', color='black', linestyle='-', linewidth=2.5)

    # Plot 1D Roofline (conditional)
    if show_1d_roofline:
        roofline_perf_1d = np.minimum(PEAK_PERF_1D_GFLOPS, oi_range * MEM_BANDWIDTH_GB_s) 
        ax.plot(oi_range, roofline_perf_1d, label=f'1D PE Array Roof (Peak: {PEAK_PERF_1D_GFLOPS:.0f} GFLOPs/s)', color='dimgray', linestyle='--', linewidth=2.5)

    # --- Plot Workload Points ---
    plotted_ois = []
    plotted_perfs = []

    for wl_data in workload_data_list:
        flops = wl_data.get('flops', 0)
        bytes_val = wl_data.get('bytes', 0)
        
        if bytes_val <= 0 or flops <=0: 
            continue # Skip points with invalid data

        oi = flops / bytes_val
        pe_type = wl_data.get('pe_type', 'unknown')
        
        achieved_perf = 0
        # Calculate performance based on PE type
        if pe_type == '2d':
            achieved_perf = get_achieved_perf(oi, PEAK_PERF_2D_GFLOPS, MEM_BANDWIDTH_GB_s, RIDGE_POINT_2D)
        elif pe_type == '1d':
            # Only plot 1D points if the 1D roofline is being shown
            if show_1d_roofline:
                achieved_perf = get_achieved_perf(oi, PEAK_PERF_1D_GFLOPS, MEM_BANDWIDTH_GB_s, RIDGE_POINT_1D)
            else:
                continue # Skip 1D points if 1D roof is hidden
        else:
            continue # Skip unknown PE types

        # Plot the point if performance is valid
        if oi > 0 and achieved_perf > 0:
            ax.plot(oi, achieved_perf, marker=wl_data.get('marker', 'o'), markersize=11, linestyle='None', 
                    label=f"{wl_data.get('label','Unknown')} ({pe_type.upper()})", color=wl_data.get('color', 'blue'), 
                    markeredgewidth=0.8, markeredgecolor='black') # Added edge for clarity
            plotted_ois.append(oi)
            plotted_perfs.append(achieved_perf)

    # --- Axis Setup ---
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Operational Intensity (FLOPs/Byte)')
    ax.set_ylabel('Performance (GFLOPs/s)')
    ax.set_title(title)
    
    # --- Set Axis Limits ---
    # Use fixed limits if provided, otherwise calculate dynamically
    if fixed_xlim:
        ax.set_xlim(fixed_xlim)
    else:
        # Dynamic OI limit calculation (fallback)
        current_oi_min = oi_min_plot_default
        current_oi_max = oi_max_plot_default
        if plotted_ois: 
            log_oi_min = np.log10(min(plotted_ois))
            log_oi_max = np.log10(max(plotted_ois))
            current_oi_min = min(oi_min_plot_default, 10**(log_oi_min - (log_oi_max - log_oi_min) * 0.1)) if min(plotted_ois) > 0 else oi_min_plot_default
            current_oi_max = max(oi_max_plot_default, 10**(log_oi_max + (log_oi_max - log_oi_min) * 0.2)) if max(plotted_ois) > 0 else oi_max_plot_default
        ax.set_xlim(current_oi_min, current_oi_max)

    if fixed_ylim:
        ax.set_ylim(fixed_ylim)
    else:
        # Dynamic Performance limit calculation (fallback)
        current_perf_min = perf_min_plot_default
        current_perf_max = perf_max_plot_limit_default # Start with roof-based limit
        if plotted_perfs:
            log_perf_min = np.log10(min(plotted_perfs))
            log_perf_max = np.log10(max(plotted_perfs))
            current_perf_min = min(perf_min_plot_default, 10**(log_perf_min - (log_perf_max - log_perf_min) * 0.1)) if min(plotted_perfs) > 0 else perf_min_plot_default
            # Ensure upper limit includes the relevant peak performance + buffer based on plotted points
            peak_to_consider = PEAK_PERF_2D_GFLOPS if not show_1d_roofline else max(PEAK_PERF_1D_GFLOPS, PEAK_PERF_2D_GFLOPS)
            current_perf_max = max(peak_to_consider * 1.5, 10**(log_perf_max + (log_perf_max - log_perf_min) * 0.2)) if max(plotted_perfs) > 0 else perf_max_plot_limit_default
        ax.set_ylim(current_perf_min, current_perf_max)
    
    # --- Legend and Grid ---
    handles, labels = ax.get_legend_handles_labels()
    num_items = len(handles)
    legend_cols = 1 if num_items <= 6 else 2 # Adjust columns for readability
    legend_fontsize = plt.rcParams['legend.fontsize'] 
    if num_items > 12: 
         legend_fontsize -= 2 # Reduce size if very crowded
    
    ax.legend(handles=handles, labels=labels, fontsize=legend_fontsize, loc='lower right', ncol=legend_cols, framealpha=0.8) 
    ax.grid(True, which="both", ls="--", alpha=0.4, color='gray') # Lighter grid


# --- Helper function to calculate FLOPs and Bytes for Transformer Components (FuseMax with SRAM constraint) ---
def calculate_transformer_layer_components_fusemax(model_prefix, n_seq, d_model, n_heads, d_ff, 
                                                 attn_color='red', mlp_color='green', overall_color='blue',
                                                 attn_marker='o', mlp_marker='o', overall_marker='D'):
    """Calculates FLOPs and Bytes for Attn, MLP, and Overall Layer (FuseMax),
       considering SRAM capacity for weights and allowing custom styling."""
    # --- [Calculation logic remains the same as previous version] ---
    d_head = d_model // n_heads
    components = []
    debug_prints = False # Set to True to see SRAM penalty messages

    # 1. Attention Core (FuseMax)
    flops_qk_av_per_head = 2 * (n_seq**2 * d_head)
    flops_softmax_per_head = 3 * (n_seq**2)
    total_flops_core_attn = n_heads * (flops_qk_av_per_head * 2 + flops_softmax_per_head)
    bytes_core_attn = (4 * n_seq * d_model) * BYTES_PER_ELEMENT_BF16
    components.append({
        'label': f'{model_prefix} Attn', 'flops': total_flops_core_attn, 'bytes': bytes_core_attn,
        'pe_type': '2d', 'color': attn_color, 'marker': attn_marker
    })
    
    # 2. MLP (FuseMax)
    flops_gemm1_mlp = 2 * n_seq * d_ff * d_model
    flops_activation_mlp = GELU_FLOPS_PER_ELEMENT * n_seq * d_ff
    flops_gemm2_mlp = 2 * n_seq * d_model * d_ff
    total_flops_mlp = flops_gemm1_mlp + flops_activation_mlp + flops_gemm2_mlp
    
    mlp_gemm1_weight_bytes = d_model * d_ff * BYTES_PER_ELEMENT_BF16
    mlp_gemm2_weight_bytes = d_ff * d_model * BYTES_PER_ELEMENT_BF16
    
    adjusted_mlp_gemm1_w_bytes = mlp_gemm1_weight_bytes
    if mlp_gemm1_weight_bytes > SRAM_CAPACITY_BYTES:
        penalty_factor1 = mlp_gemm1_weight_bytes / SRAM_CAPACITY_BYTES
        adjusted_mlp_gemm1_w_bytes = mlp_gemm1_weight_bytes * penalty_factor1
        if debug_prints: print(f"INFO: {model_prefix} MLP GEMM1 weights ({mlp_gemm1_weight_bytes/1024/1024:.2f}MB) exceed SRAM ({SRAM_CAPACITY_BYTES/1024/1024:.2f}MB). Penalty: {penalty_factor1:.2f}x")

    adjusted_mlp_gemm2_w_bytes = mlp_gemm2_weight_bytes
    if mlp_gemm2_weight_bytes > SRAM_CAPACITY_BYTES:
        penalty_factor2 = mlp_gemm2_weight_bytes / SRAM_CAPACITY_BYTES
        adjusted_mlp_gemm2_w_bytes = mlp_gemm2_weight_bytes * penalty_factor2
        if debug_prints: print(f"INFO: {model_prefix} MLP GEMM2 weights ({mlp_gemm2_weight_bytes/1024/1024:.2f}MB) exceed SRAM ({SRAM_CAPACITY_BYTES/1024/1024:.2f}MB). Penalty: {penalty_factor2:.2f}x")

    bytes_mlp_weights_total_adjusted = adjusted_mlp_gemm1_w_bytes + adjusted_mlp_gemm2_w_bytes
    bytes_mlp_activations = ( (n_seq * d_model) + (n_seq * d_model) ) * BYTES_PER_ELEMENT_BF16
    bytes_mlp = bytes_mlp_activations + bytes_mlp_weights_total_adjusted
    
    components.append({
        'label': f'{model_prefix} MLP', 'flops': total_flops_mlp, 'bytes': bytes_mlp,
        'pe_type': '2d', 'color': mlp_color, 'marker': mlp_marker
    })

    # 3. Overall Layer (FuseMax)
    flops_attn_projections = 4 * (2 * n_seq * d_model**2) 
    flops_layernorm_op = LAYERNORM_FLOPS_PER_ELEMENT * n_seq * d_model
    total_flops_overall = flops_attn_projections + total_flops_core_attn + total_flops_mlp + 2 * flops_layernorm_op
    
    one_attn_proj_weight_bytes = (d_model**2) * BYTES_PER_ELEMENT_BF16
    adjusted_one_attn_proj_w_bytes = one_attn_proj_weight_bytes
    if one_attn_proj_weight_bytes > SRAM_CAPACITY_BYTES:
        penalty_factor_attn = one_attn_proj_weight_bytes / SRAM_CAPACITY_BYTES
        adjusted_one_attn_proj_w_bytes = one_attn_proj_weight_bytes * penalty_factor_attn
        if debug_prints: print(f"INFO: {model_prefix} Attn Proj weights ({one_attn_proj_weight_bytes/1024/1024:.2f}MB per proj) exceed SRAM ({SRAM_CAPACITY_BYTES/1024/1024:.2f}MB). Penalty: {penalty_factor_attn:.2f}x")

    bytes_overall_weights_attn_proj_adjusted = adjusted_one_attn_proj_w_bytes * 4
    bytes_overall_activations = (2 * n_seq * d_model) * BYTES_PER_ELEMENT_BF16
    total_bytes_overall = bytes_overall_activations + bytes_overall_weights_attn_proj_adjusted + bytes_mlp_weights_total_adjusted
    
    components.append({
        'label': f'{model_prefix} Overall', 'flops': total_flops_overall, 'bytes': total_bytes_overall,
        'pe_type': '2d', 'color': overall_color, 'marker': overall_marker
    })
    return components

# --- Data Preparation ---
# (Data preparation for plots 1-4 remains the same as the previous version)
# --- Data Preparation for Plot 1: BERT Component Operations & Baselines ---
workloads_for_plot1 = []
bert_components_fusemax = calculate_transformer_layer_components_fusemax(
    "BERT", N_SEQ_REF_BERT, D_MODEL_BERT, N_HEADS_BERT, D_FF_BERT,
    attn_color='firebrick', mlp_color='forestgreen', overall_color='royalblue', 
    attn_marker='o', mlp_marker='o', overall_marker='D'
)
bert_attn_fusemax_data = next(c for c in bert_components_fusemax if "Attn" in c["label"])
bert_mlp_fusemax_data = next(c for c in bert_components_fusemax if "MLP" in c["label"])
bert_overall_fusemax_data = next(c for c in bert_components_fusemax if "Overall" in c["label"])

workloads_for_plot1.append({**bert_attn_fusemax_data, 'label': 'Attn (FuseMax-BERT)'})
workloads_for_plot1.append({**bert_mlp_fusemax_data, 'label': 'MLP (FuseMax-BERT)'})
workloads_for_plot1.append({**bert_overall_fusemax_data, 'label': 'Overall (FuseMax-BERT)'})

bytes_core_attn_unfused_bert = bert_attn_fusemax_data['bytes'] * 2.5
workloads_for_plot1.append({
    'label': 'Attn (Unfused-BERT)', 'flops': bert_attn_fusemax_data['flops'], 'bytes': bytes_core_attn_unfused_bert,
    'pe_type': '2d', 'color': 'darkorange', 'marker': 'X' 
})
mlp_activation_bytes_bert_unfused = ( (N_SEQ_REF_BERT * D_MODEL_BERT) + 
                                (N_SEQ_REF_BERT * D_FF_BERT) * 4 + 
                                (N_SEQ_REF_BERT * D_MODEL_BERT)   
                              ) * BYTES_PER_ELEMENT_BF16
mlp_weight_bytes_bert_unfused = ( (D_MODEL_BERT * D_FF_BERT) + (D_FF_BERT * D_MODEL_BERT) ) * BYTES_PER_ELEMENT_BF16 
bytes_mlp_unfused_bert = mlp_activation_bytes_bert_unfused + mlp_weight_bytes_bert_unfused
workloads_for_plot1.append({
    'label': 'MLP (Unfused-BERT)', 'flops': bert_mlp_fusemax_data['flops'], 'bytes': bytes_mlp_unfused_bert,
    'pe_type': '2d', 'color': 'gold', 'marker': 'X' 
})
bytes_core_attn_flat_bert = bert_attn_fusemax_data['bytes'] * 1.75
workloads_for_plot1.append({
    'label': 'Attn (FLAT-BERT)', 'flops': bert_attn_fusemax_data['flops'], 'bytes': bytes_core_attn_flat_bert,
    'pe_type': '2d', 'color': 'lightcoral', 'marker': 'P' 
})
bytes_mlp_flat_bert = (bert_mlp_fusemax_data['bytes'] + bytes_mlp_unfused_bert) / 2.2 
workloads_for_plot1.append({
    'label': 'MLP (FLAT-BERT)', 'flops': bert_mlp_fusemax_data['flops'], 'bytes': bytes_mlp_flat_bert,
    'pe_type': '2d', 'color': 'yellowgreen', 'marker': 'P' 
})

# Add 1D operations ONLY to Plot 1
flops_softmax_1d_bert = 3 * (N_SEQ_REF_BERT**2) 
bytes_softmax_1d_bert = (N_SEQ_REF_BERT**2 * BYTES_PER_ELEMENT_BF16) * 2 
workloads_for_plot1.append({'label': 'Softmax (1D)', 'flops': flops_softmax_1d_bert * N_HEADS_BERT, 'bytes': bytes_softmax_1d_bert * N_HEADS_BERT, 'pe_type': '1d', 'color': 'magenta', 'marker': 's'})
flops_gelu_1d_bert = GELU_FLOPS_PER_ELEMENT * N_SEQ_REF_BERT * D_FF_BERT
bytes_gelu_1d_bert = (N_SEQ_REF_BERT * D_FF_BERT * BYTES_PER_ELEMENT_BF16) * 2
workloads_for_plot1.append({'label': 'GELU (1D)', 'flops': flops_gelu_1d_bert, 'bytes': bytes_gelu_1d_bert, 'pe_type': '1d', 'color': 'cyan', 'marker': 's'})
flops_layernorm_1d_bert = LAYERNORM_FLOPS_PER_ELEMENT * N_SEQ_REF_BERT * D_MODEL_BERT
bytes_layernorm_1d_bert = (N_SEQ_REF_BERT * D_MODEL_BERT * BYTES_PER_ELEMENT_BF16) * 2
workloads_for_plot1.append({'label': 'LayerNorm (1D)', 'flops': flops_layernorm_1d_bert, 'bytes': bytes_layernorm_1d_bert, 'pe_type': '1d', 'color': 'orange', 'marker': 's'})

# --- Data Preparation for Plot 2: BERT Overall Layer (Varying Sequence Lengths) ---
workloads_for_plot2 = []
seq_length_configs_plot2 = [
    {'label_suffix': 'N_seq=256 (Short)', 'N': 256, 'color': 'darkviolet', 'marker':'P'}, # Changed N back to 256
    {'label_suffix': f'N_seq={N_SEQ_REF_BERT} (Medium)', 'N': N_SEQ_REF_BERT, 'color': 'royalblue', 'marker':'D'},
    {'label_suffix': 'N_seq=4096 (Long)', 'N': 4096, 'color': 'saddlebrown', 'marker':'X'} 
]
for config in seq_length_configs_plot2:
    n_seq = config['N']
    bert_overall_components = calculate_transformer_layer_components_fusemax(
        "BERT", n_seq, D_MODEL_BERT, N_HEADS_BERT, D_FF_BERT,
        overall_color=config['color'], overall_marker=config['marker'] 
    )
    overall_data = next(c for c in bert_overall_components if "Overall" in c["label"])
    workloads_for_plot2.append({
        **overall_data, 'label': f'BERT Overall ({config["label_suffix"]})'
    })
# DO NOT add 1D ops to Plot 2

# --- Data Preparation for Plot 3: OPT & Pythia Components (FuseMax, N_SEQ_REF_OTHERS) ---
N_SEQ_REF_OTHERS = 2048 
workloads_for_plot3 = []
opt_components = calculate_transformer_layer_components_fusemax(
    "OPT", N_SEQ_REF_OTHERS, D_MODEL_OPT, N_HEADS_OPT, D_FF_OPT,
    attn_color='purple', mlp_color='orange', overall_color='red',
    attn_marker='o', mlp_marker='o', overall_marker='D' 
)
workloads_for_plot3.extend(opt_components)

pythia_components = calculate_transformer_layer_components_fusemax(
    "Pythia", N_SEQ_REF_OTHERS, D_MODEL_PYTHIA, N_HEADS_PYTHIA, D_FF_PYTHIA,
    attn_color='green', mlp_color='indigo', overall_color='yellow',
    attn_marker='^', mlp_marker='^', overall_marker='P' 
)
workloads_for_plot3.extend(pythia_components)
# DO NOT add 1D ops to Plot 3

# --- Data Preparation for Plot 4: Overall Performance (BERT, OPT, Pythia - Varying Contexts) ---
workloads_for_plot4 = []
seq_length_configs_plot4 = [
    {'label_suffix': 'N_seq=256 (Short)', 'N': 256, 'marker': 'P'}, # Changed N back to 256
    {'label_suffix': 'N_seq=4096 (Long)', 'N': 4096, 'marker': 'D'}
]
model_configs_plot4 = [
    {'prefix': 'BERT', 'd_model': D_MODEL_BERT, 'n_heads': N_HEADS_BERT, 'd_ff': D_FF_BERT, 'color': 'royalblue'},
    {'prefix': 'OPT', 'd_model': D_MODEL_OPT, 'n_heads': N_HEADS_OPT, 'd_ff': D_FF_OPT, 'color': 'indigo'},
    {'prefix': 'Pythia', 'd_model': D_MODEL_PYTHIA, 'n_heads': N_HEADS_PYTHIA, 'd_ff': D_FF_PYTHIA, 'color': 'darkslategray'}
]

for model_cfg in model_configs_plot4:
    for seq_cfg in seq_length_configs_plot4:
        n_seq = seq_cfg['N']
        components = calculate_transformer_layer_components_fusemax(
            model_cfg['prefix'], n_seq, model_cfg['d_model'], model_cfg['n_heads'], model_cfg['d_ff'],
            overall_color=model_cfg['color'], overall_marker=seq_cfg['marker']
        )
        overall_data = next(c for c in components if "Overall" in c["label"])
        workloads_for_plot4.append({
            **overall_data,
            'label': f'{model_cfg["prefix"]} Overall ({seq_cfg["label_suffix"]})'
        })
# DO NOT add 1D ops to Plot 4


# --- Calculate Global Axis Limits Across All Plots ---
all_workloads_combined = workloads_for_plot1 + workloads_for_plot2 + workloads_for_plot3 + workloads_for_plot4
min_oi_global = float('inf')
max_oi_global = float('-inf')
min_perf_global = float('inf')
max_perf_global = float('-inf')

for wl in all_workloads_combined:
    flops = wl.get('flops', 0)
    bytes_val = wl.get('bytes', 0)
    pe_type = wl.get('pe_type', 'unknown')

    if bytes_val <= 0 or flops <= 0:
        continue
    
    oi = flops / bytes_val
    
    # Determine performance based on PE type
    achieved_perf = 0
    if pe_type == '2d':
        achieved_perf = get_achieved_perf(oi, PEAK_PERF_2D_GFLOPS, MEM_BANDWIDTH_GB_s, RIDGE_POINT_2D)
    elif pe_type == '1d': 
        # Only consider 1D points if they are present (i.e., from plot 1)
         if any(w['pe_type'] == '1d' for w in workloads_for_plot1): # Check if 1D points exist at all
              achieved_perf = get_achieved_perf(oi, PEAK_PERF_1D_GFLOPS, MEM_BANDWIDTH_GB_s, RIDGE_POINT_1D)
         else: 
              continue # Skip if no 1D points are expected
    else:
        continue

    if oi > 0 and achieved_perf > 0:
        min_oi_global = min(min_oi_global, oi)
        max_oi_global = max(max_oi_global, oi)
        min_perf_global = min(min_perf_global, achieved_perf)
        max_perf_global = max(max_perf_global, achieved_perf)

# Include roofline peaks in max performance consideration
max_perf_global = max(max_perf_global, PEAK_PERF_2D_GFLOPS)
# Only include 1D peak if Plot 1 (which shows 1D) is generated
if any(w['pe_type'] == '1d' for w in workloads_for_plot1):
     max_perf_global = max(max_perf_global, PEAK_PERF_1D_GFLOPS)


# Define padding factors for log scale
oi_pad_factor_low = 0.1  # e.g., 10^ (log10(min) * (1-pad)) -> divide by 10^0.1 ~ 1.25
oi_pad_factor_high = 0.3 # e.g., 10^ (log10(max) * (1+pad)) -> multiply by 10^0.3 ~ 2
perf_pad_factor_low = 0.1
perf_pad_factor_high = 0.2

# Calculate final padded limits, ensuring they are positive
final_oi_min = 10**(np.log10(min_oi_global) - (np.log10(max_oi_global) - np.log10(min_oi_global)) * oi_pad_factor_low) if min_oi_global > 0 and max_oi_global > 0 else 0.01
final_oi_max = 10**(np.log10(max_oi_global) + (np.log10(max_oi_global) - np.log10(min_oi_global)) * oi_pad_factor_high) if min_oi_global > 0 and max_oi_global > 0 else 30000
final_perf_min = 10**(np.log10(min_perf_global) - (np.log10(max_perf_global) - np.log10(min_perf_global)) * perf_pad_factor_low) if min_perf_global > 0 and max_perf_global > 0 else 10
final_perf_max = 10**(np.log10(max_perf_global) + (np.log10(max_perf_global) - np.log10(min_perf_global)) * perf_pad_factor_high) if min_perf_global > 0 and max_perf_global > 0 else PEAK_PERF_2D_GFLOPS * 2

# Ensure minimums don't go below reasonable defaults
final_oi_min = max(0.01, final_oi_min)
final_perf_min = max(10, final_perf_min)

# Define the fixed limits as tuples
final_xlim = (final_oi_min, final_oi_max)
final_ylim = (final_perf_min, final_perf_max)

print(f"Global Axis Limits Set:")
print(f"  X-Axis (OI): {final_xlim}")
print(f"  Y-Axis (Perf): {final_ylim}")

# --- Create and Save Figures ---

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Plot 1
fig1, ax1 = plt.subplots(figsize=(12, 9)) # Slightly larger figure size
plot_roofline_generic(fig1, ax1, f'Plot 1: BERT Component Ops & Baselines (N_seq={N_SEQ_REF_BERT})', 
                      workloads_for_plot1, show_1d_roofline=True, 
                      fixed_xlim=final_xlim, fixed_ylim=final_ylim) # Pass fixed limits
fig1.savefig(os.path.join(output_dir, "roofline_plot_1_bert_baselines.jpeg"), bbox_inches='tight', dpi=500)
plt.close(fig1) 

# Plot 2
fig2, ax2 = plt.subplots(figsize=(12, 9))
plot_roofline_generic(fig2, ax2, 'Plot 2: BERT Overall Layer - FuseMax (Varying Seq Length)', 
                      workloads_for_plot2, show_1d_roofline=False, 
                      fixed_xlim=final_xlim, fixed_ylim=final_ylim) # Pass fixed limits
fig2.savefig(os.path.join(output_dir, "roofline_plot_2_bert_varying_seq.jpeg"), bbox_inches='tight', dpi=500)
plt.close(fig2)

# Plot 3
fig3, ax3 = plt.subplots(figsize=(12, 9))
plot_roofline_generic(fig3, ax3, f'Plot 3: OPT & Pythia Components - FuseMax (N_seq={N_SEQ_REF_OTHERS}, SRAM Constraint)', 
                      workloads_for_plot3, show_1d_roofline=False, 
                      fixed_xlim=final_xlim, fixed_ylim=final_ylim) # Pass fixed limits
fig3.savefig(os.path.join(output_dir, "roofline_plot_3_opt_pythia_components.jpeg"), bbox_inches='tight', dpi=500)
plt.close(fig3)

# Plot 4
fig4, ax4 = plt.subplots(figsize=(12, 9))
plot_roofline_generic(fig4, ax4, 'Plot 4: Model Overall Layer - FuseMax (Varying Seq Length, SRAM Constraint)', 
                      workloads_for_plot4, show_1d_roofline=False, 
                      fixed_xlim=final_xlim, fixed_ylim=final_ylim) # Pass fixed limits
fig4.savefig(os.path.join(output_dir, "roofline_plot_4_overall_comparison.jpeg"), bbox_inches='tight', dpi=500)
plt.close(fig4)

print(f"Roofline plots saved to directory: {output_dir}")

# --- Output calculated values for verification (Optional) ---
# (Keep print_output logic as before if needed for debugging)
print_output = True # Set to False to disable printouts
if print_output:
    print("\n--- System & Roofline Parameters ---")
 
    print(f"Memory Bandwidth: {MEM_BANDWIDTH_GB_s} GB/s")
    print(f"2D PE Array: {PE_ROWS_2D}x{PE_COLS_2D} PEs")
    print(f"  Peak Performance (2D): {PEAK_PERF_2D_GFLOPS:.2f} GFLOPs/s ({PEAK_PERF_2D_GFLOPS/1000:.2f} TFLOPs/s)")
    print(f"  Ridge Point (2D): {RIDGE_POINT_2D:.2f} FLOPs/Byte")
    print(f"1D PE Array: 1x{NUM_PES_1D} PEs")
    print(f"  Peak Performance (1D): {PEAK_PERF_1D_GFLOPS:.2f} GFLOPs/s")
    print(f"  Ridge Point (1D): {RIDGE_POINT_1D:.2f} FLOPs/Byte")

    all_plots_data = {
        f"Plot 1 (BERT Components, N_seq={N_SEQ_REF_BERT})": workloads_for_plot1,
        "Plot 2 (BERT Overall, Varying N_seq)": workloads_for_plot2,
        f"Plot 3 (OPT/Pythia Components, N_seq={N_SEQ_REF_OTHERS})": workloads_for_plot3,
        "Plot 4 (All Models Overall, Varying N_seq)": workloads_for_plot4,
    }

    for plot_name, workloads in all_plots_data.items():
        print(f"\n--- Workloads for {plot_name} ---")
        for wl in workloads:
            oi = 0
            if wl.get('bytes', 0) > 0 and wl.get('flops', 0) > 0:
                oi = wl['flops'] / wl['bytes']
            
            peak_p = PEAK_PERF_2D_GFLOPS if wl['pe_type']=='2d' else PEAK_PERF_1D_GFLOPS
            ridge_p = RIDGE_POINT_2D if wl['pe_type']=='2d' else RIDGE_POINT_1D
            perf = get_achieved_perf(oi, peak_p, MEM_BANDWIDTH_GB_s, ridge_p)
            print(f"  {wl['label']:<45} ({wl['pe_type']}): FLOPs={wl['flops']:.2e}, Bytes={wl['bytes']:.2e}, OI={oi:.2f}, Est. Perf={perf/1000 if perf >=1000 else perf:.1f} {'TFLOPs/s' if perf >=1000 else 'GFLOPs/s'}")
# Out:
# Global Axis Limits Set:
#   X-Axis (OI): (np.float64(0.3164996779046972), np.float64(55719.23518047689))
#   Y-Axis (Perf): (np.float64(164.3499598051711), np.float64(410526.394420279))
# Roofline plots saved to directory: ./roofline_plots
#
# --- System & Roofline Parameters ---
# Memory Bandwidth: 400 GB/s
# 2D PE Array: 256x256 PEs
#   Peak Performance (2D): 123207.68 GFLOPs/s (123.21 TFLOPs/s)
#   Ridge Point (2D): 308.02 FLOPs/Byte
# 1D PE Array: 1x256 PEs
#   Peak Performance (1D): 481.28 GFLOPs/s
#   Ridge Point (1D): 1.20 FLOPs/Byte
#
# --- Workloads for Plot 1 (BERT Components, N_seq=1024) ---
#   Attn (FuseMax-BERT)                           (2d): FLOPs=4.35e+09, Bytes=8.39e+06, OI=518.00, Est. Perf=123.2 TFLOPs/s
#   MLP (FuseMax-BERT)                            (2d): FLOPs=1.72e+10, Bytes=3.77e+07, OI=456.22, Est. Perf=123.2 TFLOPs/s
#   Overall (FuseMax-BERT)                        (2d): FLOPs=3.02e+10, Bytes=4.61e+07, OI=653.86, Est. Perf=123.2 TFLOPs/s
#   Attn (Unfused-BERT)                           (2d): FLOPs=4.35e+09, Bytes=2.10e+07, OI=207.20, Est. Perf=82.9 TFLOPs/s
#   MLP (Unfused-BERT)                            (2d): FLOPs=1.72e+10, Bytes=5.45e+07, OI=315.85, Est. Perf=123.2 TFLOPs/s
#   Attn (FLAT-BERT)                              (2d): FLOPs=4.35e+09, Bytes=1.47e+07, OI=296.00, Est. Perf=118.4 TFLOPs/s
#   MLP (FLAT-BERT)                               (2d): FLOPs=1.72e+10, Bytes=4.19e+07, OI=410.60, Est. Perf=123.2 TFLOPs/s
#   Softmax (1D)                                  (1d): FLOPs=5.03e+07, Bytes=6.71e+07, OI=0.75, Est. Perf=300.0 GFLOPs/s
#   GELU (1D)                                     (1d): FLOPs=4.19e+07, Bytes=1.68e+07, OI=2.50, Est. Perf=481.3 GFLOPs/s
#   LayerNorm (1D)                                (1d): FLOPs=5.24e+06, Bytes=4.19e+06, OI=1.25, Est. Perf=481.3 GFLOPs/s
#
# --- Workloads for Plot 2 (BERT Overall, Varying N_seq) ---
#   BERT Overall (N_seq=256 (Short))              (2d): FLOPs=6.73e+09, Bytes=4.30e+07, OI=156.48, Est. Perf=62.6 TFLOPs/s
#   BERT Overall (N_seq=1024 (Medium))            (2d): FLOPs=3.02e+10, Bytes=4.61e+07, OI=653.86, Est. Perf=123.2 TFLOPs/s
#   BERT Overall (N_seq=4096 (Long))              (2d): FLOPs=1.73e+11, Bytes=5.87e+07, OI=2943.00, Est. Perf=123.2 TFLOPs/s
#
# --- Workloads for Plot 3 (OPT/Pythia Components, N_seq=2048) ---
#   OPT Attn                                      (2d): FLOPs=1.56e+11, Bytes=1.51e+08, OI=1030.00, Est. Perf=123.2 TFLOPs/s
#   OPT MLP                                       (2d): FLOPs=2.78e+12, Bytes=2.20e+11, OI=12.64, Est. Perf=5.1 TFLOPs/s
#   OPT Overall                                   (2d): FLOPs=4.33e+12, Bytes=2.48e+11, OI=17.48, Est. Perf=7.0 TFLOPs/s
#   Pythia Attn                                   (2d): FLOPs=2.20e+09, Bytes=2.10e+06, OI=1048.00, Est. Perf=123.2 TFLOPs/s
#   Pythia MLP                                    (2d): FLOPs=5.47e+08, Bytes=1.31e+06, OI=417.60, Est. Perf=123.2 TFLOPs/s
#   Pythia Overall                                (2d): FLOPs=3.02e+09, Bytes=1.44e+06, OI=2092.00, Est. Perf=123.2 TFLOPs/s
#
# --- Workloads for Plot 4 (All Models Overall, Varying N_seq) ---
#   BERT Overall (N_seq=256 (Short))              (2d): FLOPs=6.73e+09, Bytes=4.30e+07, OI=156.48, Est. Perf=62.6 TFLOPs/s
#   BERT Overall (N_seq=4096 (Long))              (2d): FLOPs=1.73e+11, Bytes=5.87e+07, OI=2943.00, Est. Perf=123.2 TFLOPs/s
#   OPT Overall (N_seq=256 (Short))               (2d): FLOPs=5.24e+11, Bytes=2.48e+11, OI=2.12, Est. Perf=846.9 GFLOPs/s
#   OPT Overall (N_seq=4096 (Long))               (2d): FLOPs=8.97e+12, Bytes=2.48e+11, OI=36.21, Est. Perf=14.5 TFLOPs/s
#   Pythia Overall (N_seq=256 (Short))            (2d): FLOPs=1.37e+08, Bytes=5.24e+05, OI=260.62, Est. Perf=104.2 TFLOPs/s
#   Pythia Overall (N_seq=4096 (Long))            (2d): FLOPs=1.04e+10, Bytes=2.49e+06, OI=4187.37, Est. Perf=123.2 TFLOPs/s

# %%
# Out:
# Global Axis Limits Set:
#   X-Axis (OI): (0.32, 55719.24)
#   Y-Axis (Perf): (164.35, 410526.39)
# Roofline plots saved to directory: ./roofline_plots
